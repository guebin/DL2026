# %% [raw]
# ---
# title: "프로젝트4: 나만의 이미지수집 및 분석 (2026.06.05 - 2026.06.12)"
# author: "최규빈"
# date: "08/04/2026"
# draft: false
# freeze: true
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/DL2026/blob/master/posts/Prj4.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# `(1)` 프로젝트3의 코드를 참고하여, **본인이 직접 정한 주제**로 이미지를 수집하고 분류하라. 단, **강의에서 이미 다룬 주제는 사용 금지**한다. (예: `cat` / `dog`, `ariana` / `taylor`)

# %% [markdown]
# `(2)` 학습한 네트워크 `net` 을 이용하여, 임의의 이미지 URL을 입력하면 그 이미지를 불러와 **그림을 그려주고 예측값(softmax 확률)·예측클래스를 출력**하는 함수를 구현하라.
