# %% [raw]
# ---
# title: "**10wk-1: CPU와 GPU**"
# author: "최규빈"
# date: "05/11/2026 13:00"
# draft: false
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/DL2026/blob/master/posts/10wk-1.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# # 1. 강의영상

# %% [markdown]
# {{<video https://youtu.be/playlist?list=PLQqh36zP38-zCxpUJ7HErPrSsG_gNCB80&si=H7eIf_GXnOZsi3Y3>}}

# %% [markdown]
# # 2. Imports

# %%
import torch
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (4.5,3.0)

# %% [markdown]
# # 3. CPU vs GPU

# %% [markdown]
# `-` 컴퓨터에 대한 상식
#
# - 연산: CPU 혹은 GPU
# - 값이저장되는곳: 시스템 RAM, GPU RAM

# %% [markdown]
# `-` 일반적으로는 시스템RAM에 값을 저장하고 CPU를 이용하여 연산하지만, 때로는 GPU RAM에 값을 저장하고 GPU를 이용하여 연산하는 경우도 있음.

# %% [markdown]
# `-` GPU가 사용가능한 상태인지 확인해야함. 그 명령어가 아래와 같음

# %%
# !nvidia-smi # GPU가 사용하지 않음
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# `-` GPU를 할당받는 방법: "런타임 $\to$ 런타임 유형 변경 $\to$ T4 GPU"

# %%
# !nvidia-smi # GPU가 사용하지 않음
# Out:
# Sat May  9 20:23:05 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8             15W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## A. CPU/GPU를 이용한 연산

# %% [markdown]
# `-` cpu를 이용한 연산

# %%
Xcpu = torch.tensor([0.0,0.1,0.2]).reshape(-1,1)
net = torch.nn.Linear(1,1)

# %%
net(Xcpu)
# Out:
# tensor([[-0.5513],
#         [-0.5226],
#         [-0.4938]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# `-` gpu를 이용한 연산

# %%
Xgpu = Xcpu.to("cuda:0")
Xgpu
# Out:
# tensor([[0.0000],
#         [0.1000],
#         [0.2000]], device='cuda:0')

# %%
net(Xgpu) # 단순하게 아래와 같이 하면 error가 발생함
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2726/3328533530.py in <cell line: 0>()
# ----> 1 net(Xgpu)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# ...

# %%
net.weight, net.bias # 왜?? net.weight, net.bias가 모두 GPU RAM이 아니라 시스템 RAM에 저장되어있기 떄문
# Out:
# (Parameter containing:
#  tensor([[0.2875]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.5513], requires_grad=True))

# %%
net.to("cuda:0") # 시스템 RAM에 있는 net의 파라메터들을 GPU RAM으로 옮기는 명령어
# Out:
# Linear(in_features=1, out_features=1, bias=True)

# %%
net.weight, net.bias # 옮겨짐
# Out:
# (Parameter containing:
#  tensor([[0.2875]], device='cuda:0', requires_grad=True),
#  Parameter containing:
#  tensor([-0.5513], device='cuda:0', requires_grad=True))

# %%
net(Xgpu) # 이제 연산가능
# Out:
# tensor([[-0.5513],
#         [-0.5226],
#         [-0.4938]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# `-` 정리하면, gpu는 gpu끼리 연산가능하고 cpu는 cpu까리 연산가능

# %% [markdown]
# (예시1)

# %%
net.to("cpu")
net(Xcpu)
# Out:
# tensor([[-0.5513],
#         [-0.5226],
#         [-0.4938]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# (예시2)

# %%
net.to("cuda:0")
net(Xgpu)
# Out:
# tensor([[-0.5513],
#         [-0.5226],
#         [-0.4938]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# (예시3)

# %%
net.to("cpu")
net(Xgpu)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2726/3607595623.py in <cell line: 0>()
#       1 net.to("cpu")
# ----> 2 net(Xgpu)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
# ...

# %% [markdown]
# (예시4)

# %%
net.to("cuda:0")
net(Xcpu)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2726/2084202529.py in <cell line: 0>()
#       1 net.to("cuda:0")
# ----> 2 net(Xcpu)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
# ...

# %% [markdown]
# (예시5)

# %%
net.to("cpu")
Ycpu = torch.tensor([0.0,0.2,0.4]).reshape(-1,1)
torch.mean((Ycpu-net(Xcpu))**2)
# Out:
# tensor(0.5416, grad_fn=<MeanBackward0>)

# %% [markdown]
# (예시6)

# %%
net.to("cuda:0")
Ygpu = torch.tensor([0.0,0.2,0.4]).reshape(-1,1).to("cuda:0")
torch.mean((Ygpu-net(Xgpu))**2)
# Out:
# tensor(0.5416, device='cuda:0', grad_fn=<MeanBackward0>)

# %% [markdown]
# (예시7)

# %%
net.to("cpu")
torch.mean((Ygpu-net(Xcpu))**2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2726/2207204121.py in <cell line: 0>()
#       1 net.to("cpu")
# ----> 2 torch.mean((Ygpu-net(Xcpu))**2)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!

# %% [markdown]
# (예시8)

# %%
net.to("cuda:0")
torch.mean((Ycpu-net(Xgpu))**2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2726/1283262321.py in <cell line: 0>()
#       1 net.to("cuda:0")
# ----> 2 torch.mean((Ycpu-net(Xgpu))**2)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!

# %% [markdown]
# ## B. 시간측정 (예비학습)

# %%
import time

# %%
t1 = time.time()

# %%
t2 = time.time()

# %%
t2-t1
# Out:
# 3.3674073219299316

# %% [markdown]
# ## C. CPU vs GPU

# %% [markdown]
# `-` CPU (512)

# %%
X = torch.randn(100,1)
Y = torch.randn(100,1)
net = torch.nn.Sequential(
    torch.nn.Linear(1,512),
    torch.nn.ReLU(),
    torch.nn.Linear(512,1),
)
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(net.parameters())
#---#
t1 = time.time()
for epoch in range(1000):
    # 1
    Yhat = net(X)
    # 2
    loss = loss_fn(Yhat,Y)
    # 3
    loss.backward()
    # 4
    optimizer.step()
    optimizer.zero_grad()
t2 = time.time()
t2-t1
# Out:
# 1.0356519222259521

# %% [markdown]
# `-` GPU (512)

# %%
X = torch.randn(100,1).to("cuda:0")
Y = torch.randn(100,1).to("cuda:0")
net = torch.nn.Sequential(
    torch.nn.Linear(1,512),
    torch.nn.ReLU(),
    torch.nn.Linear(512,1),
).to("cuda:0")
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(net.parameters())
#---#
t1 = time.time()
for epoch in range(1000):
    # 1
    Yhat = net(X)
    # 2
    loss = loss_fn(Yhat,Y)
    # 3
    loss.backward()
    # 4
    optimizer.step()
    optimizer.zero_grad()
t2 = time.time()
t2-t1
# Out:
# 1.468613862991333

# %% [markdown]
# `-` CPU (20480)

# %%
X = torch.randn(100,1)
Y = torch.randn(100,1)
net = torch.nn.Sequential(
    torch.nn.Linear(1,20480),
    torch.nn.ReLU(),
    torch.nn.Linear(20480,1),
)
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(net.parameters())
#---#
t1 = time.time()
for epoch in range(1000):
    # 1
    Yhat = net(X)
    # 2
    loss = loss_fn(Yhat,Y)
    # 3
    loss.backward()
    # 4
    optimizer.step()
    optimizer.zero_grad()
t2 = time.time()
t2-t1
# Out:
# 10.478125095367432

# %% [markdown]
# `-` GPU (20480)

# %%
X = torch.randn(100,1).to("cuda:0")
Y = torch.randn(100,1).to("cuda:0")
net = torch.nn.Sequential(
    torch.nn.Linear(1,20480),
    torch.nn.ReLU(),
    torch.nn.Linear(20480,1),
).to("cuda:0")
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(net.parameters())
#---#
t1 = time.time()
for epoch in range(1000):
    # 1
    Yhat = net(X)
    # 2
    loss = loss_fn(Yhat,Y)
    # 3
    loss.backward()
    # 4
    optimizer.step()
    optimizer.zero_grad()
t2 = time.time()
t2-t1
# Out:
# 1.4007525444030762

# %% [markdown]
# - 왜 이런차이가 나는가?
# - CPU는 연산은 빠르지만 코어숫자가 적고, GPU는 연산은 느리지만 코어숫자가 많기 떄문

# %% [markdown]
# `-` CPU (204800)

# %%
X = torch.randn(100,1)
Y = torch.randn(100,1)
net = torch.nn.Sequential(
    torch.nn.Linear(1,204800),
    torch.nn.ReLU(),
    torch.nn.Linear(204800,1),
)
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(net.parameters())
#---#
t1 = time.time()
for epoch in range(1000):
    # 1
    Yhat = net(X)
    # 2
    loss = loss_fn(Yhat,Y)
    # 3
    loss.backward()
    # 4
    optimizer.step()
    optimizer.zero_grad()
t2 = time.time()
t2-t1
# Out:
# 248.22365045547485

# %%
X = torch.randn(100,1).to("cuda:0")
Y = torch.randn(100,1).to("cuda:0")
net = torch.nn.Sequential(
    torch.nn.Linear(1,204800),
    torch.nn.ReLU(),
    torch.nn.Linear(204800,1),
).to("cuda:0")
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(net.parameters())
#---#
t1 = time.time()
for epoch in range(1000):
    # 1
    Yhat = net(X)
    # 2
    loss = loss_fn(Yhat,Y)
    # 3
    loss.backward()
    # 4
    optimizer.step()
    optimizer.zero_grad()
t2 = time.time()
t2-t1
# Out:
# 4.633766412734985
