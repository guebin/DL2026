# %% [raw]
# ---
# title: "Quiz-9 (2026.04.06) // 범위: ~04wk"
# author: "최규빈"
# date: "04/06/2026"
# draft: false
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/DL2026/blob/master/posts/Quiz9.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %%
import torch

# %% [markdown]
# # 1. 베르누이 MLE

# %% [markdown]
# 아래는 $X_i \overset{iid}{\sim} Ber(0.8)$을 생성하는 코드이다.

# %%
torch.manual_seed(43052)
x = torch.bernoulli(torch.tensor([0.8]*10000))

# %% [markdown]
# 함수 $l(p)$를 최소화하는 $p$를 경사하강법으로 추정하라.

# %% [markdown]
# $$l(p) = -\frac{1}{n}\sum_{i=1}^{n} \log f(x_i), \quad f(x_i) = p^{x_i} (1-p)^{1-x_i}$$

# %% [markdown]
# > 단, 초기값은 $p=0.5$ 에서 시작할 것

# %% [markdown]
# *hint: 이론적인 수렴값은 `x.mean()`임.*
