# %% [raw]
# ---
# title: "A2: 벡터와 행렬"
# author: "최규빈"
# date: "03/08/2026"
# ---

# %% [markdown]
# # 1. 강의영상

# %% [markdown]
# {{<video https://youtu.be/playlist?list=PLQqh36zP38-ynH5qUeDhk6iHJmTuzIQwm&si=7MgwXqqxyPoFgggc>}}
